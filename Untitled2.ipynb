# %%
numero1 = int(input("Dame un numero"))
numero2= int(input("Dame un numero"))
if numeros1 > numeros2 :
    print("es mayor que:",numero1)
elif numero1 < numero2 :
    print("es menor que:",numero2)
elif numero1 ==numero2:
    print("son iguales")
# Out:
# Dame un numero4
# Dame un numero5
# es menor que: 5

# %%
"Determina el mayor de los 3 numeros ingresados"
n1 = int(input("Dame un numero"))
n2 =int(input("Dame un numero"))
n3 = int(input("Dame un numero"))
if n1 >n2 and n1 >n3 : 
    print("el numero mayor es :",numero1)
elif n2 >n1 and n2 >n3 :
    print("el numero mayor es :",numero2)
elif n3 >n1 and n3 >n2 :
    print("el numero mayor es :", numero3)
# Out:
# Dame un numero6
# Dame un numero8
# Dame un numero0
# el numero mayor es : 2

# %%
n1 = int(input("Dame un numero"))
n2 = int(input("Dame un numero"))       
n3 = int(input("Dame un numero"))
n4 = int(input("Dame un numero"))
if n1 > n2 and n1 > n3 and n1 > n4 :
    print("El numero mayor es:",n1)
elif n2 > n1 and n2 > n3 and n2 > n4 :
    print("El mayor numero es :",n2)
elif n3 > n1 and n3 > n2 and n3 > n4 :
    print("el numero mayor es:",n3)
elif n4 > n1 and n4 > n2 and n4 > n3 :
    print("El numero mayor es:",n4)
# Out:
# Dame un numero5
# Dame un numero6
# Dame un numero7
# Dame un numero8
# El numero mayor es: 8
